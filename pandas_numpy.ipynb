# %%
import pandas as pd

# %%
MyClass = { 'John':10, 'Jake':9, 'Jackie':8, 'Jack':7, 'Jane':6, 'Jo':10, 'Ja':9, 'Jac':8, 'Jacky':7 , 'Jan':6 }

# %%
df = pd.DataFrame(MyClass, index =[1,2,3])

# %%
df
# Out:
#    John  Jake  Jackie  Jack  Jane  Jo  Ja  Jac  Jacky  Jan
# 1    10     9       8     7     6  10   9    8      7    6
# 2    10     9       8     7     6  10   9    8      7    6
# 3    10     9       8     7     6  10   9    8      7    6

# %%
df1 = pd.DataFrame(MyClass,index=[0])
df1
# Out:
#    John  Jake  Jackie  Jack  Jane  Jo  Ja  Jac  Jacky  Jan
# 0    10     9       8     7     6  10   9    8      7    6

# %%
MyInventory = {
    "Item": ["coffee", "chocolate", "tea", "water"],
    "Promotion": ["yes", "no", "yes", "no"],
    "Price": [5.95, 5.95, 3.95, 2.95],
    "Stock": [100, 250, 1000, 1200]
    }

# %%
MyInventory
# Out:
# {'Item': ['coffee', 'chocolate', 'tea', 'water'],
#  'Promotion': ['yes', 'no', 'yes', 'no'],
#  'Price': [5.95, 5.95, 3.95, 2.95],
#  'Stock': [100, 250, 1000, 1200]}

# %%
df2=pd.DataFrame(MyInventory)
df2
# Out:
#         Item Promotion  Price  Stock
# 0     coffee       yes   5.95    100
# 1  chocolate        no   5.95    250
# 2        tea       yes   3.95   1000
# 3      water        no   2.95   1200

# %%
df = pd.read_excel('QtyDemand.xlsx')

# %%
df
# Out:
#    Price  Sales  Quantity
# 0     50      9       7.1
# 1     50      9       5.7
# 2     60     11       5.7
# 3     60     11       6.6
# 4     70     13      13.2
# 5     70     13       9.7
# 6     80     15      11.3
# 7     80     15      15.6

# %%
df1 = pd.read_excel ('QtyDemand.xlsx',usecols =[0])

# %%
df1
# Out:
#    Price
# 0     50
# 1     50
# 2     60
# 3     60
# 4     70
# 5     70
# 6     80
# 7     80

# %%
df2=pd.read_excel('QtyDemand.xlsx',usecols=[0,2])
df2
# Out:
#    Price  Quantity
# 0     50       7.1
# 1     50       5.7
# 2     60       5.7
# 3     60       6.6
# 4     70      13.2
# 5     70       9.7
# 6     80      11.3
# 7     80      15.6

# %%
df3 = pd.read_excel('QtyDemand.xlsx',usecols=["Price","Quantity"])
df3
# Out:
#    Price  Quantity
# 0     50       7.1
# 1     50       5.7
# 2     60       5.7
# 3     60       6.6
# 4     70      13.2
# 5     70       9.7
# 6     80      11.3
# 7     80      15.6

# %%
#Save specific columns to excel
df3.to_csv("testqty10.csv")

# %%
#Save the columns without index to the excel
df3.to_csv("testqty11.csv",index=False)

# %%
#Save those to the excel file
df3.to_excel("testqty12.xlsx")

# %% [markdown]
# # Numpy

# %% [markdown]
# Now, we will integrate Numpy with Pandas to show more advanced functions, and play with those.

# %%
#read csv file into data frame first
df = pd.read_csv('Cookies dirty data.csv')

# %%
df
# Out:
#          Date        Day  Temperature Salesman Tweets  Price Sales
# 0    1/1/2019    Tuesday         72.0     John      2    0.5   177
# 1         NaN        NaN          NaN      NaN    NaN    NaN   NaN
# 2    1/3/2019   Thursday         69.0     John      5    0.5   172
# 3    1/4/2019     Friday        100.0     John      7    0.5   150
# 4         NaN        NaN          NaN      NaN    NaN    NaN   NaN
# 5    1/6/2019     Sunday         91.0      Ada      8    0.5   120
# 6    1/7/2019     Monday         81.0      Ada      3    0.3    96
# 7         NaN        NaN          NaN      NaN    NaN    NaN   NaN
# 8    1/9/2019  Wednesday         69.0     John      8    0.5   177
# 9   1/10/2019   Thursday         61.0     John     10    0.5   190
# 10  1/11/2019     Friday         79.0     John      1    0.5   154
# 11  1/12/2019   Saturday         94.0     John      H    0.5   160
# 12  1/13/2019     Sunday         80.0     John      5    0.5   161
# ...

# %% [markdown]
# As a data scientist, after obtaining the raw data, we will first do the data cleaning and data sorting.

# %% [markdown]
# The second step, we usually do the data processing that includes normalization, categorization, and we will also do some basic statistics analysis.

# %% [markdown]
# The third step, is usually doing the visualization, tabalization, and also some test (i.e., test is about mathematics, data science, etc. verification).

# %% [markdown]
# In the following step, we are going to use some advanced machine learning for forecasting, deep learning for the classification, Convolutionary Neural Network, etc. Besides, there will be tons of algorithms, advanced mathematics technology and some other STEM techniques for the processing.

# %%
# We do the data cleaning first for the Cookies Dirty Data (i.e., the Cookie raw data)
df.dropna(how='all', inplace=True)
df
# Out:
#          Date        Day  Temperature Salesman Tweets  Price Sales
# 0    1/1/2019    Tuesday         72.0     John      2    0.5   177
# 2    1/3/2019   Thursday         69.0     John      5    0.5   172
# 3    1/4/2019     Friday        100.0     John      7    0.5   150
# 5    1/6/2019     Sunday         91.0      Ada      8    0.5   120
# 6    1/7/2019     Monday         81.0      Ada      3    0.3    96
# 8    1/9/2019  Wednesday         69.0     John      8    0.5   177
# 9   1/10/2019   Thursday         61.0     John     10    0.5   190
# 10  1/11/2019     Friday         79.0     John      1    0.5   154
# 11  1/12/2019   Saturday         94.0     John      H    0.5   160
# 12  1/13/2019     Sunday         80.0     John      5    0.5   161
# 13  1/14/2019     Monday         64.0     John      8    0.5   185
# 14  1/15/2019    Tuesday         94.0      Ada      6    0.5   137
# 15  1/16/2019  Wednesday         68.0      Ada      5    0.3     $
# ...

# %%
# remove leading/trailing spaces
df["Salesman"] = df["Salesman"].str.strip()

# %%
df
# Out:
#          Date        Day  Temperature Salesman Tweets  Price Sales
# 0    1/1/2019    Tuesday         72.0     John      2    0.5   177
# 2    1/3/2019   Thursday         69.0     John      5    0.5   172
# 3    1/4/2019     Friday        100.0     John      7    0.5   150
# 5    1/6/2019     Sunday         91.0      Ada      8    0.5   120
# 6    1/7/2019     Monday         81.0      Ada      3    0.3    96
# 8    1/9/2019  Wednesday         69.0     John      8    0.5   177
# 9   1/10/2019   Thursday         61.0     John     10    0.5   190
# 10  1/11/2019     Friday         79.0     John      1    0.5   154
# 11  1/12/2019   Saturday         94.0     John      H    0.5   160
# 12  1/13/2019     Sunday         80.0     John      5    0.5   161
# 13  1/14/2019     Monday         64.0     John      8    0.5   185
# 14  1/15/2019    Tuesday         94.0      Ada      6    0.5   137
# 15  1/16/2019  Wednesday         68.0      Ada      5    0.3     $
# ...

# %%
# Replace invalid values with NaN for multiple columns ()
